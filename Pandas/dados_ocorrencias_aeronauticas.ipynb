# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium as fl

df = pd.read_csv("V_OCORRENCIA_AMPLA.csv", sep= ";", encoding= "utf-8", header= 1)
df.dtypes
# Out:
# Numero_da_Ocorrencia                  int64
# Numero_da_Ficha                      object
# Operador_Padronizado                 object
# Classificacao_da_Ocorrencia          object
# Data_da_Ocorrencia                   object
# Hora_da_Ocorrencia                   object
# Municipio                            object
# UF                                   object
# Regiao                               object
# Descricao_do_Tipo                    object
# ICAO                                 object
# Latitude                             object
# Longitude                            object
# Tipo_de_Aerodromo                    object
# Historico                            object
# Matricula                            object
# Categoria_da_Aeronave                object
# Operador                             object
# Tipo_de_Ocorrencia                   object
# Fase_da_Operacao                     object
# Operacao                             object
# ...

# %%
df_ig = df[df["Classificacao_da_Ocorrencia"] == "Incidente Grave"]
df_ig
# Out:
#       Numero_da_Ocorrencia Numero_da_Ficha  \
# 8                    27045       202107020
# 12                   27047       202103837
# 13                   25324       202027489
# 21                   27123       202167613
# 23                   25923       202008607
# ...                    ...             ...
# 5010                 33446      2022809448
# 5011                 34407      2022130140
# 5012                 34407      2022130140
# 5016                 36306      2023466783
# 5018                 36348      2023242037
#
#                        Operador_Padronizado Classificacao_da_Ocorrencia  \
# 8              VIAGRO VIDOTTI AERO AGRICOLA             Incidente Grave
# 12        CORPO DE BOMB.MIL.DO ESTADO DO RJ             Incidente Grave
# 13    WESCON COBRANÇAS E PARTICIPAÇÕES LTDA             Incidente Grave
# 21          LUSA AVIACAO AGRICOLA LTDA - ME             Incidente Grave
# 23        CARLOS ALBERTO MENDES VASCONCELOS             Incidente Grave
# ...

# %%
print(df.iloc[6]["Historico"])
# Out:
# A aeronave decolou da Ilha do Cavaco (SIVA), Angra dos Reis - RJ com destino ao Hotel do Bosque (ZZZZ) com um piloto a bordo. Durante a aproximação para pouso a aeronave colidiu contra fiação da torre de transmissão de energia elétrica. A aeronave teve danos substanciais. O piloto sofreu lesão fatal. Houve dano a rede elétrica, o local ficou sem energia devido ao rompimento dos cabos.

# %%
df_valido = df.dropna(subset=['Latitude', 'Longitude'])
df_valido
# Out:
#       Numero_da_Ocorrencia Numero_da_Ficha  \
# 0                    25626       202096550
# 1                    26304       202056314
# 2                    25763       202041291
# 3                    26123       202060427
# 5                    26123       202060427
# ...                    ...             ...
# 5016                 36306      2023466783
# 5017                 36346      2023211240
# 5018                 36348      2023242037
# 5019                 36349      2023261212
# 5020                 36486      2023420958
#
#                                  Operador_Padronizado  \
# 0                  MINIST.JUST.SECRET.NAC.DE SEG.PUB.
# 1                       AERO AGRICOLA ROSARIENSE LTDA
# 2                       KAIO GENARIO FERREIRA DE MELO
# 3                      MARCIO ROBERTO SALES DE ARAUJO
# 5                      MARCIO ROBERTO SALES DE ARAUJO
# ...                                               ...
# 5016                      AGROPASTORIL SAO PEDRO LTDA
# ...

# %%
# mapa = fl.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=12)

# # Adiciona um marcador para cada ponto no DataFrame
# for index, linha in df_valido.iterrows():
#     fl.Marker(
#         location=[linha['Latitude'], linha['Longitude']],
#         popup=linha['Descricao_do_Tipo'],  # Texto que aparece ao clicar
#         tooltip=linha['Municipio'] # Texto que aparece ao passar o mouse
#     ).add_to(mapa)

# # Salva o mapa em um arquivo HTML
# mapa.save("mapa_rio.html")

# print("Mapa 'mapa_rio.html' criado com sucesso! Abra este arquivo no seu navegador.")
