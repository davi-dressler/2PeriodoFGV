# %%
import pandas as pd

df = pd.read_csv("Final_data.csv", sep= ",", header=0)
df
# Out:
#          Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0      34.91    Male        65.27        1.62   188.58   157.65        69.05
# 1      23.37  Female        56.41        1.55   179.43   131.75        73.18
# 2      33.20  Female        58.98        1.67   175.04   123.95        54.96
# 3      38.69  Female        93.78        1.70   191.21   155.10        50.07
# 4      45.09    Male        52.42        1.88   193.58   152.88        70.84
# ...      ...     ...          ...         ...      ...      ...          ...
# 19995  46.77  Female        98.31        1.90   199.20   148.18        63.72
# 19996  40.38  Female        88.12        1.87   196.18   134.18        54.04
# 19997  50.31    Male        46.20        1.67   163.34   157.92        61.65
# 19998  52.36    Male        44.30        1.62   179.27   121.23        60.88
# 19999  29.56    Male        58.63        1.61   198.07   121.74        72.05
#
# ...

# %%
df["Workout_Type"].value_counts()
# Out:
# Workout_Type
# Strength    5071
# Yoga        5032
# HIIT        4974
# Cardio      4923
# Name: count, dtype: int64

# %%
df_strength = df[df["Workout_Type"] == "Strength"]
df_strength
# Out:
#          Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0      34.91    Male        65.27        1.62   188.58   157.65        69.05
# 4      45.09    Male        52.42        1.88   193.58   152.88        70.84
# 6      23.17    Male        58.41        1.78   184.75   140.90        58.01
# 8      24.11  Female        88.58        1.79   176.78   154.07        65.19
# 9      39.19  Female        50.32        1.60   166.88   128.04        49.91
# ...      ...     ...          ...         ...      ...      ...          ...
# 19987  28.14  Female        51.76        1.61   167.94   164.21        69.88
# 19992  28.59  Female        68.43        1.70   189.81   150.29        60.09
# 19995  46.77  Female        98.31        1.90   199.20   148.18        63.72
# 19996  40.38  Female        88.12        1.87   196.18   134.18        54.04
# 19997  50.31    Male        46.20        1.67   163.34   157.92        61.65
#
# ...

# %%
df_yoga = df[df["Workout_Type"] == "Yoga"]
df_yoga
# Out:
#          Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 5      53.19  Female       105.05        1.84   176.52   130.60        61.84
# 7      55.92  Female        84.07        1.63   183.87   141.12        51.79
# 21     50.23  Female        86.72        1.63   160.86   143.17        58.08
# 25     54.03  Female        87.22        1.76   188.72   157.91        68.00
# 30     57.07  Female        76.90        1.86   173.05   140.94        55.07
# ...      ...     ...          ...         ...      ...      ...          ...
# 19988  29.95    Male        63.19        1.67   163.95   162.22        69.91
# 19989  27.97    Male        72.49        1.67   196.92   146.55        73.89
# 19994  39.38    Male        64.13        1.69   189.94   147.87        58.17
# 19998  52.36    Male        44.30        1.62   179.27   121.23        60.88
# 19999  29.56    Male        58.63        1.61   198.07   121.74        72.05
#
# ...

# %%
df_hiit = df[df["Workout_Type"] == "HIIT"]
df_hiit
# Out:
#          Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 1      23.37  Female        56.41        1.55   179.43   131.75        73.18
# 3      38.69  Female        93.78        1.70   191.21   155.10        50.07
# 11     47.77  Female        83.89        1.82   176.36   148.74        69.91
# 12     19.00    Male        82.66        1.96   173.75   168.71        62.16
# 13     38.01  Female        57.67        1.56   184.91   132.43        54.04
# ...      ...     ...          ...         ...      ...      ...          ...
# 19973  47.62  Female        85.97        1.99   181.97   152.77        69.97
# 19978  38.72    Male        85.73        1.89   163.03   139.84        61.17
# 19981  45.03  Female        59.34        1.51   169.04   141.67        65.03
# 19982  53.10    Male       115.30        1.92   192.90   160.91        50.00
# 19993  28.52  Female        87.72        1.89   199.01   136.63        53.80
#
# ...

# %%
df_cardio = df[df["Workout_Type"] == "Cardio"]
df_cardio
# Out:
#          Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 2      33.20  Female        58.98        1.67   175.04   123.95        54.96
# 17     37.14    Male        76.48        1.77   180.29   127.80        56.76
# 22     30.90  Female        76.77        1.71   189.88   137.20        51.88
# 23     24.03  Female        88.29        1.79   177.55   153.60        65.23
# 26     25.11  Female       105.44        1.88   174.12   155.79        67.11
# ...      ...     ...          ...         ...      ...      ...          ...
# 19970  46.33  Female        48.10        1.72   170.91   147.44        57.19
# 19974  24.12    Male        54.65        1.74   159.79   167.00        53.09
# 19986  46.09    Male        63.54        1.61   186.98   151.88        68.08
# 19990  49.91  Female        67.12        1.77   171.14   164.11        72.92
# 19991  51.62    Male        60.26        1.68   181.80   125.37        64.31
#
# ...
